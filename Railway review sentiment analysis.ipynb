# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Railways dataset - Sheet1.csv')

# %%
df.head()
# Out:
#                 User                                            Sub  Rating  \
# 0    aditi88ajmera\r                       Indian railways review\r       1
# 1    prateeknegi12\r              Food Quality and Staff behavior\r       1
# 2  amruthrsagar004\n                           Lack of time sence\r       1
# 3          suraaz \r  IRCTC:- Drama of sleeping by administrator \r       2
# 4      rohitut1996\r             Need to change railway minister.\r       1
#
#                                               Review Sentiment
# 0  Worst and pathetic services that anyone can pr...  Negative
# 1  PNR-2537404628\nTrn:12056\nDt:02-03-20\nFrm DD...  Negative
# 2  I've always faced this issue whenever I travel...  Negative
# 3  IRCTC:- Drama of sleeping by administrator\r\n...  Negative
# 4  Wow as you can see that cleanness of the train...  Negative

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.groupby('User')['Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# User
# bhatawdekar            5
# senthilr               5
# arbaaz1180comshie\r    5
# vbsunny                5
# melvinjohn             5
# marshale               5
# prassad_rs             5
# oyearun                5
# pcmajumdar             5
# kumkut                 5
# Name: Rating, dtype: int64

# %%
df.groupby('User')['Rating'].count().sort_values(ascending=False).head(500)
# Out:
# User
# ysravish\r            1
# himanshu_ram          1
# juggernaut            1
# johny_bravvo          1
# jharashmi1980         1
# jayeshmore513         1
# jainsidharath\r       1
# jaideep71             1
# jacksonluisa2         1
# ilyas_kantawala       1
# haldarayan0           1
# yestio                1
# geetanshutpl          1
# gauravkumar02010      1
# enidhi                1
# drvinayav1985\r       1
# devmurmu89            1
# dennyjos              1
# dcruzblossom710       1
# cskumar416            1
# kdeepak1130           1
# ketul_shah\r          1
# krishnpalchauhan      1
# kumkut                1
# nirmalasharma         1
# neodynium\r           1
# navaneethamvemula     1
# narangshiv85          1
# nambiarsu             1
# nahasmnkochi8         1
#                      ..
# pkcshekar             1
# piyushsh583           1
# piscean14             1
# phvraju               1
# philipsv              1
# pcmajumdar            1
# pattanayaksuraj623    1
# parmeet99901ps        1
# radhad23              1
# rahul_khemka          1
# sarat_dara            1
# rajasagar             1
# santulan              1
# sanjayghosh3691       1
# sandeep1096           1
# sameeraparab2003      1
# ruheenmulla95         1
# rtsnap4\r             1
# rohitut1996\r         1
# rnhotta               1
# rjois                 1
# remonchettri          1
# reejumaiti            1
# razzput               1
# rayala369srinath      1
# raty4361              1
# rasmitamuduli         1
# rameshpuru            1
# rajesh                1
# 20071992g             1
# Name: Rating, Length: 168, dtype: int64

# %%
ratings =pd.DataFrame(df.groupby('User')['Rating'].mean())

# %%
ratings.head()
# Out:
#                Rating
# User
# 20071992g           1
# AamPeople21         1
# Chintu25            2
# DGirish123456       1
# Devakumar150        2

# %%
ratings['Rating_Numbers'] = pd.DataFrame(df.groupby('User')['Rating'].count())

# %%
ratings.head()
# Out:
#                Rating  Rating_Numbers
# User
# 20071992g           1               1
# AamPeople21         1               1
# Chintu25            2               1
# DGirish123456       1               1
# Devakumar150        2               1

# %%
ratings['Rating_Numbers'].hist(bins=70)

# %%
ratings['Rating'].hist(bins=70)

# %%
sns.jointplot(x='Rating', y='Rating_Numbers', data=ratings, alpha=0.5)
# Out:
# E:\Users\Mani\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
moviemat = df.pivot_table(index='User', columns='Sub', values='Rating')
moviemat.head()
# Out:
# Sub            02151 (pune kazipet special summer train) monday  \
# User
# 20071992g                                                   NaN
# AamPeople21                                                 NaN
# Chintu25                                                    NaN
# DGirish123456                                               NaN
# Devakumar150                                                NaN
#
# Sub            06009 Train is awful as hell  1 star\r  \
# User
# 20071992g                               NaN       NaN
# AamPeople21                             NaN       NaN
# Chintu25                                NaN       NaN
# DGirish123456                           NaN       NaN
# Devakumar150                            NaN       NaN
#
# Sub            12566 Bihar sampark Kranti experience  139:Can we rely upon???  \
# User
# 20071992g                                        NaN                      NaN
# AamPeople21                                      NaN                      NaN
# Chintu25                                         NaN                      NaN
# DGirish123456                                    NaN                      NaN
# Devakumar150                                     NaN                      NaN
#
# Sub            15023 Train Review\r  22884- Puri garib Rath express.\r  \
# User
# 20071992g                       NaN                                NaN
# AamPeople21                     NaN                                NaN
# Chintu25                        NaN                                NaN
# DGirish123456                   NaN                                NaN
# Devakumar150                    NaN                                NaN
#
# Sub            A chronicle of a few journeys...  \
# User
# 20071992g                                   NaN
# AamPeople21                                 NaN
# Chintu25                                    NaN
# DGirish123456                               NaN
# Devakumar150                                NaN
#
# Sub            A special train with below average facilities  ASR HWR 13006  \
# User
# 20071992g                                                NaN            NaN
# AamPeople21                                              NaN            NaN
# Chintu25                                                 NaN            NaN
# DGirish123456                                            NaN            NaN
# Devakumar150                                             NaN            NaN
#
# Sub                      ...             Worst  Worst Indian railways service  \
# User                     ...
# 20071992g                ...               NaN                            NaN
# AamPeople21              ...               NaN                            NaN
# Chintu25                 ...               NaN                            NaN
# DGirish123456            ...               NaN                            NaN
# Devakumar150             ...               NaN                            NaN
#
# Sub            Worst experience  Worst in world\r  \
# User
# 20071992g                   NaN               1.0
# AamPeople21                 NaN               NaN
# Chintu25                    NaN               NaN
# DGirish123456               NaN               NaN
# Devakumar150                NaN               NaN
#
# Sub            Worst railways network of world  \
# User
# 20071992g                                  NaN
# AamPeople21                                NaN
# Chintu25                                   NaN
# DGirish123456                              NaN
# Devakumar150                               NaN
#
# Sub            Worst service and infrastructure  \
# User
# 20071992g                                   NaN
# AamPeople21                                 NaN
# Chintu25                                    NaN
# DGirish123456                               NaN
# Devakumar150                                NaN
#
# Sub            Worst service indian railways\r  Worst worst and worst  \
# User
# 20071992g                                  NaN                    NaN
# AamPeople21                                NaN                    NaN
# Chintu25                                   NaN                    NaN
# DGirish123456                              NaN                    NaN
# Devakumar150                               NaN                    NaN
#
# Sub            YEHI HAI ONLY CHOICE BABY  Your attention please...
# User
# 20071992g                            NaN                       NaN
# AamPeople21                          NaN                       NaN
# Chintu25                             NaN                       NaN
# DGirish123456                        NaN                       NaN
# Devakumar150                         NaN                       NaN
#
# [5 rows x 165 columns]

# %%
ratings.sort_values('Rating_Numbers', ascending=False).head(10)
# Out:
#                   Rating  Rating_Numbers
# User
# 20071992g              1               1
# rjois                  4               1
# rajesh                 5               1
# rameshpuru             1               1
# rasmitamuduli          3               1
# raty4361               3               1
# rayala369srinath       1               1
# razzput                2               1
# reejumaiti             1               1
# remonchettri           1               1

# %%
sentiment_data=[]
sentiment_data=df['Sentiment']

# %%
sentiment_data[:]
# Out:
# 0      Negative
# 1      Negative
# 2      Negative
# 3      Negative
# 4      Negative
# 5      Negative
# 6      Negative
# 7      Positive
# 8      Negative
# 9      Negative
# 10     Negative
# 11     Negative
# 12     Negative
# 13     Negative
# 14     Negative
# 15     Negative
# 16     Positive
# 17     Negative
# 18     Negative
# 19     Negative
# 20     Negative
# 21     Negative
# 22     Negative
# 23     Negative
# 24     Positive
# 25     Negative
# 26     Positive
# 27     Positive
# 28     Negative
# 29     Negative
#          ...
# 138    Positive
# 139    Positive
# 140    Negative
# 141    Negative
# 142    Positive
# 143    Positive
# 144    Positive
# 145    Positive
# 146    Positive
# 147    Negative
# 148    Positive
# 149    Negative
# 150    Positive
# 151    Positive
# 152    Positive
# 153    Positive
# 154    Positive
# 155    Negative
# 156    Positive
# 157    Positive
# 158    Negative
# 159    Positive
# 160    Positive
# 161    Negative
# 162    Positive
# 163    Positive
# 164    Negative
# 165    Negative
# 166    Negative
# 167    Negative
# Name: Sentiment, Length: 168, dtype: object

# %%
df.keys()
# Out:
# Index(['User', 'Sub', 'Rating', 'Review', 'Sentiment'], dtype='object')

# %%
sentiment_data[:].to_csv('sentiment_data.csv')

# %%
sen_data = []
for sentiment in sentiment_data[:]:
    if sentiment == "Positive":
        sen_data.append('1')
    else:
        sen_data.append('0')

# %%
df['Sentiment_Data'] = sen_data

# %%
df.head()
# Out:
#                 User                                            Sub  Rating  \
# 0    aditi88ajmera\r                       Indian railways review\r       1
# 1    prateeknegi12\r              Food Quality and Staff behavior\r       1
# 2  amruthrsagar004\n                           Lack of time sence\r       1
# 3          suraaz \r  IRCTC:- Drama of sleeping by administrator \r       2
# 4      rohitut1996\r             Need to change railway minister.\r       1
#
#                                               Review Sentiment Sentiment_Data
# 0  Worst and pathetic services that anyone can pr...  Negative              0
# 1  PNR-2537404628\nTrn:12056\nDt:02-03-20\nFrm DD...  Negative              0
# 2  I've always faced this issue whenever I travel...  Negative              0
# 3  IRCTC:- Drama of sleeping by administrator\r\n...  Negative              0
# 4  Wow as you can see that cleanness of the train...  Negative              0

# %%
ratings =pd.DataFrame(df.groupby('User')['Sentiment_Data'].count())

# %%
ratings.head()
# Out:
#                Sentiment_Data
# User
# 20071992g                   1
# AamPeople21                 1
# Chintu25                    1
# DGirish123456               1
# Devakumar150                1

# %%
df[:20].plot(x= 'User', y = 'Rating', kind = 'bar')

# %%
df.loc[0:100,"User":"Review"]
# Out:
#                      User                                                Sub  \
# 0         aditi88ajmera\r                           Indian railways review\r
# 1         prateeknegi12\r                  Food Quality and Staff behavior\r
# 2       amruthrsagar004\n                               Lack of time sence\r
# 3               suraaz \r      IRCTC:- Drama of sleeping by administrator \r
# 4           rohitut1996\r                 Need to change railway minister.\r
# 5             shashi855\r                                             Late\r
# 6      viraktishirodkar\r      Review for train no 01664...Hbj dharwad exp\r
# 7               rtsnap4\r                              Train travelling time
# 8             haldarayan0                                Regarding Toilets\r
# 9              devmurmu89               Bad performance of Indian railways\r
# 10      amitkumar198917\r         Very bad performance of Indian railways.\r
# 11       mittalinnovation                      Very ill responsible staff.\r
# 12        satisharohana\r                                Train 12770 delay\r
# 13            ppsingh82\r                                        Big Shock\r
# 14   satyaprakash101991\r                    No Refund For Cancelled Train\r
# 15             boobaneric              Delay....mostly delay,always delay.\r
# 16      virendradaveadv\r                         Honest Railway attendent\r
# 17      lokeshkumark395\r                                         Train time
# 18        jainsidharath\r  Traveling from Chennai to Tiruchirapalli tejas...
# 19             rameshpuru          Huge room to Improve Traveling Pleasure\r
# 20               skale183                                    Railway india\r
# 21        rahul081nalanda                Train 12551, yeshvantpur-kamakhya\r
# 22              uworld121                               15023 Train Review\r
# 23      nishikaprajapati3  I am reviewing about kota udaipur special train\r
# 24           suvidsystems                  22884- Puri garib Rath express.\r
# 25        drvinayav1985\r                                  Indian railways\r
# 26           banilonnet\r         Locating Seat Numbers On A Premium Train\r
# 27    arbaaz1180comshie\r                Indian Railways are god for us...\r
# 28             ysravish\r          One of the worst system in the universe\r
# 29          ruheenmulla95                                Jabalpur Sf train\r
# ..                    ...                                                ...
# 71             reejumaiti      A special train with below average facilities
# 72             cskumar416                Most cheating Train in Duranto list
# 73           amankumar444             Eastern railway is in its worst peak\r
# 74             Nirupama87                   Frustated with railway condition
# 75           shubhamnegi9               Pathetic condition of indian railway
# 76              shimpal94                              Worst worst and worst
# 77        vashupandey2807         Too hard for Indian Railway to run on time
# 78             shisarquam                   Worst service and infrastructure
# 79              shrutikhl      Lucknow Delhi shatabdi is in a very bad state
# 80            RajeevRajan                                   Regret / NA / WL
# 81          jayeshmore513                                              Worst
# 82              yeshuindu                                  About Howrah Mail
# 83                rnhotta                    SHALIMAR TRIVANDRUM EXP JOURNEY
# 84                vbsunny              Tickets for Mumbai travel on 25th May
# 85          nirmalasharma                                   Rajdhani express
# 86               stlindia                                   Bad experience\r
# 87              nambiarsu  TicketReservation Eating into the aam-aadmis q...
# 88                phvraju        Mumbai CST Railways A/C delux Retiring Room
# 89                ashu2pp     Cheaing:IRCTC Premium Trains- Exorbitant Rates
# 90            AamPeople21                             Pathetic premium train
# 91        sanjayghosh3691           Cheating of passengers by catering staff
# 92                 Edyboy                         Needs some major changes\r
# 93               senthilr  How to make use of the Indian Railways to the ...
# 94              prabhayen                             Travel to Secunderabad
# 95               ashokakk                      Worst Indian railways service
# 96               skdonweb  Money extraction business by catering service\r\n
# 97          bhupendershrm    Never Travel by Rajdhani/Duronto Express Trains
# 98           remonchettri                       Indian Rail..hamesha Fail!!!
# 99              suneel117      Trainenquiry.com wont update at some stations
# 100            ababhishek                      Let's not criticize ourselves
#
#      Rating                                             Review
# 0         1  Worst and pathetic services that anyone can pr...
# 1         1  PNR-2537404628\nTrn:12056\nDt:02-03-20\nFrm DD...
# 2         1  I've always faced this issue whenever I travel...
# 3         2  IRCTC:- Drama of sleeping by administrator\r\n...
# 4         1  Wow as you can see that cleanness of the train...
# 5         1  I am a passenger of Indian railway since my ch...
# 6         1  First of all please remove that express tag fr...
# 7         3  Pune hamsafar santragachi express. Although it...
# 8         2  Dear IR, Appreciate your effort on providing t...
# 9         1  Hello friend I am dev and today I will share m...
# 10        1  Hello friends today I want to share my bad exp...
# 11        1  Hello friends today I want to share my bad exp...
# 12        3  Worst time mangmnt, secbad to tirupati seven h...
# 13        1  I have just cancelled online ticket from pune ...
# 14        2  20th Feb, 2016. I went to old Delhi Railway st...
# 15        1  Delay is the norm of indian railways.Ministry ...
# 16        3  I arrived at chennai railway station by pnr no...
# 17        1  No train reaches station on schedule. It is be...
# 18        1  I am traveling on tejas express dated 21/01/20...
# 19        1  I Ised to travel 30 years before and in 2020. ...
# 20        1  One of the foolish Dept in India..not a single...
# 21        1  1) 3AC - cleanliness - 3 out of 5\r\n\r\n2) To...
# 22        1  Very worst experience to travel in this train ...
# 23        1  Train name: kota udaipur special\r\n\r\nTrain ...
# 24        4  Break fast - you will get at Diguvametta, Hot ...
# 25        1  My parents booked the Bangalore Mysore Tippy e...
# 26        3  At first I thought I was an Elitist Fool who h...
# 27        5  I love them like them they are best in the wor...
# 28        1  I don't have option to give -10 so I am giving...
# 29        1  I just want to say people who think this train...
# ..      ...                                                ...
# 71        1  This so called special train, MAS-SRC AC Speci...
# 72        1  22203 & 22204 SC-VSKP DURANTO\r\n\r\ncheating ...
# 73        1  Train no. 04205\r\n\r\nWhy is it so necessary ...
# 74        3  Currently railway condition is so worst. I was...
# 75        3  The level of frustration become worse when it ...
# 76        1  I m writing this with the sense of frustration...
# 77        1  Especially the NE railway always runs late. If...
# 78        1  Never ever a train reaches on time. they are j...
# 79        1  This train is delayed by 12-15 hours daily and...
# 80        1  It is with a sense of frustration that I write...
# 81        2  Disgusting.need lost more to do.like cleaning....
# 82        1  This is the first time I have travelled and ab...
# 83        1  Dear readers,\r\n\r\nOn 3rd May 2015 I started...
# 84        5  I have 2 tickets(and 1 child ticket) for trave...
# 85        2  Every year two to three times I use to travel ...
# 86        1  Recently, I traveled by two Shatabdi trains i....
# 87        3  I tried to book a railway ticket today at 08:0...
# 88        1  I booked Mumbai CST railways retiring room A/C...
# 89        1  After paying premium fees the expectation of a...
# 90        1  This us the condition of Lucknow premium train...
# 91        2  I recently traveled by the New Delhi - Bhubane...
# 92        1  I am not discouraging or talking about the neg...
# 93        5  I have seen many people discussing about the g...
# 94        1  The South Central Railway is testing the patie...
# 95        1  Indian railway service are worst Every time th...
# 96        1  Recently, I travelled by Rajdhani express from...
# 97        1  I have made several trips by Rajdhani and Duro...
# 98        1  First Things First is one needs to be real luc...
# 99        3  For the train delay time I visited http://www....
# 100       4  Every time I board a train I have a new and wo...
#
# [101 rows x 4 columns]

# %%
permanent = df[['User', 'Sub', 'Rating', 'Review']]
print(permanent.isnull().any()) #Checking for null values
permanent.head()
# Out:
# User      False
# Sub       False
# Rating    False
# Review    False
# dtype: bool
#                 User                                            Sub  Rating  \
# 0    aditi88ajmera\r                       Indian railways review\r       1
# 1    prateeknegi12\r              Food Quality and Staff behavior\r       1
# 2  amruthrsagar004\n                           Lack of time sence\r       1
# 3          suraaz \r  IRCTC:- Drama of sleeping by administrator \r       2
# 4      rohitut1996\r             Need to change railway minister.\r       1
#
#                                               Review
# 0  Worst and pathetic services that anyone can pr...
# 1  PNR-2537404628\nTrn:12056\nDt:02-03-20\nFrm DD...
# 2  I've always faced this issue whenever I travel...
# 3  IRCTC:- Drama of sleeping by administrator\r\n...
# 4  Wow as you can see that cleanness of the train...

# %%
check =  permanent[permanent["Rating"].isnull()]
check.head()
# Out:
# Empty DataFrame
# Columns: [User, Sub, Rating, Review]
# Index: []

# %%
senti= permanent[permanent["Rating"].notnull()]
permanent.head()
# Out:
#                 User                                            Sub  Rating  \
# 0    aditi88ajmera\r                       Indian railways review\r       1
# 1    prateeknegi12\r              Food Quality and Staff behavior\r       1
# 2  amruthrsagar004\n                           Lack of time sence\r       1
# 3          suraaz \r  IRCTC:- Drama of sleeping by administrator \r       2
# 4      rohitut1996\r             Need to change railway minister.\r       1
#
#                                               Review
# 0  Worst and pathetic services that anyone can pr...
# 1  PNR-2537404628\nTrn:12056\nDt:02-03-20\nFrm DD...
# 2  I've always faced this issue whenever I travel...
# 3  IRCTC:- Drama of sleeping by administrator\r\n...
# 4  Wow as you can see that cleanness of the train...

# %%
senti["senti"] = senti["Rating"]>=4
senti["senti"] = senti["senti"].replace([True , False] , ["pos" , "neg"])

# %%
senti["senti"].value_counts().plot.bar()

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
import numpy as np
import re
import string
import nltk

cleanup_re = re.compile('[^a-z]+')
def cleanup(sentence):
    sentence = sentence.lower()
    sentence = cleanup_re.sub(' ', sentence).strip()
    #sentence = " ".join(nltk.word_tokenize(sentence))
    return sentence

senti["Summary_Clean"] = senti["Review"].apply(cleanup)
check["Summary_Clean"] = check["Review"].apply(cleanup)

# %%
split = senti[["Summary_Clean" , "senti"]]
train=split.sample(frac=0.8,random_state=200)
test=split.drop(train.index)

# %%
def word_feats(words):
    features = {}
    for word in words:
        features [word] = True
    return features

# %%
train["words"] = train["Summary_Clean"].str.lower().str.split()
test["words"] = test["Summary_Clean"].str.lower().str.split()
check["words"] = check["Summary_Clean"].str.lower().str.split()

train.index = range(train.shape[0])
test.index = range(test.shape[0])
check.index = range(check.shape[0])
prediction =  {} ## For storing results of different classifiers

train_naive = []
test_naive = []
check_naive = []

for i in range(train.shape[0]):
    train_naive = train_naive +[[word_feats(train["words"][i]) , train["senti"][i]]]
for i in range(test.shape[0]):
    test_naive = test_naive +[[word_feats(test["words"][i]) , test["senti"][i]]]
for i in range(check.shape[0]):
    check_naive = check_naive +[word_feats(check["words"][i])]


classifier = NaiveBayesClassifier.train(train_naive)
print("NLTK Naive bayes Accuracy : {}".format(nltk.classify.util.accuracy(classifier , test_naive)))
classifier.show_most_informative_features(5)
# Out:
# NLTK Naive bayes Accuracy : 0.17647058823529413
# Most Informative Features
#                   prasad = True              pos : neg    =     16.4 : 1.0
#                 official = True              pos : neg    =     16.4 : 1.0
#                ticketing = True              pos : neg    =     14.2 : 1.0
#                   choice = True              pos : neg    =     12.8 : 1.0
#                     cash = True              pos : neg    =     12.8 : 1.0

# %%
from sklearn.metrics import roc_curve, auc

# %%
def formatt(x):
    if x == 'neg':
        return 0
    return 1
vfunc = np.vectorize(formatt)

cmp = 0
colors = ['b', 'g', 'y', 'm', 'k']
for model, predicted in prediction.items():
    false_positive_rate, true_positive_rate, thresholds = roc_curve(test["senti"].map(formatt), vfunc(predicted))
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate, colors[cmp], label='%s: AUC %0.2f'% (model,roc_auc))
    cmp += 1
plt.legend(loc='lower right')
plt.title('Classifiers comparaison with ROC')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# No handles with labels found to put in legend.
